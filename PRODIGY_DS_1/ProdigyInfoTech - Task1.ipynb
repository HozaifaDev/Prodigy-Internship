# %% [markdown]
# #### Reading Data

# %%
import pandas as pd

df1 = pd.read_excel('F:\\Career\\Interns\\Sep 2024 - Prodigy InfoTech\\PRODIGY_DS_1\\data\\Data01.xlsx')
df2 = pd.read_excel('F:\\Career\\Interns\\Sep 2024 - Prodigy InfoTech\\PRODIGY_DS_1\\data\\Data02.xlsx')
df3 = pd.read_excel('F:\\Career\\Interns\\Sep 2024 - Prodigy InfoTech\\PRODIGY_DS_1\\data\\Data03.xlsx')

# %%
df1.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2014         2015         2016         2017  \
# ...

# %%
df2.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName
# 0                        Aruba
# 1  Africa Eastern and Southern
# 2                  Afghanistan
# 3   Africa Western and Central
# 4                       Angola

# %%
df3.head()
# Out:
#   INDICATOR_CODE     INDICATOR_NAME  \
# 0    SP.POP.TOTL  Population, total
#
#                                          SOURCE_NOTE  \
# 0  Total population is based on the de facto defi...
#
#                                  SOURCE_ORGANIZATION
# 0  (1) United Nations Population Division. World ...

# %%
f1 = df1.columns
f2 = df2.columns
f3 = df3.columns

print(f'1st dataframe features: \n {f1}')
print('--------------------------------------')
print(f'2nd dataframe features: \n {f2}')
print('--------------------------------------')
print(f'3rd dataframe features: \n {f3}')
# Out:
# 1st dataframe features:
#  Index([  'Country Name',   'Country Code', 'Indicator Name', 'Indicator Code',
#                    1960,             1961,             1962,             1963,
#                    1964,             1965,             1966,             1967,
#                    1968,             1969,             1970,             1971,
#                    1972,             1973,             1974,             1975,
#                    1976,             1977,             1978,             1979,
#                    1980,             1981,             1982,             1983,
#                    1984,             1985,             1986,             1987,
#                    1988,             1989,             1990,             1991,
#                    1992,             1993,             1994,             1995,
#                    1996,             1997,             1998,             1999,
#                    2000,             2001,             2002,             2003,
# ...

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### Frist Table Preprocessing

# %%
# Display each column info: Dtype and Rows count
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
# Check if there is any null data
df1.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              2
#                  ..
# 2019              1
# 2020              1
# 2021              1
# 2022              1
# 2023              1
# Length: 68, dtype: int64

# %%
# Display the null data to determine how to handle it
df1[df1[1960].isnull()]
# Out:
#            Country Name Country Code     Indicator Name Indicator Code  1960  \
# 110      Not classified          INX  Population, total    SP.POP.TOTL   NaN
# 196  West Bank and Gaza          PSE  Population, total    SP.POP.TOTL   NaN
#
#      1961  1962  1963  1964  1965  ...       2014       2015       2016  \
# 110   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 196   NaN   NaN   NaN   NaN   NaN  ...  4173398.0  4270092.0  4367088.0
#
#           2017       2018       2019       2020       2021       2022  \
# 110        NaN        NaN        NaN        NaN        NaN        NaN
# 196  4454805.0  4569087.0  4685306.0  4803269.0  4922749.0  5043612.0
#
#           2023
# 110        NaN
# 196  5165775.0
#
# [2 rows x 68 columns]

# %%
# Check if there is any more than 2 null data (just in case)
null_counts = df1.isnull().sum()
columns_with_nulls = null_counts[null_counts > 2]
columns_with_nulls
# Out:
# Series([], dtype: int64)

# %%
# Check if there is any other country name called "Not classified"
df1[df1['Country Name']=='Not classified']
# Out:
#        Country Name Country Code     Indicator Name Indicator Code  1960  \
# 110  Not classified          INX  Population, total    SP.POP.TOTL   NaN
#
#      1961  1962  1963  1964  1965  ...  2014  2015  2016  2017  2018  2019  \
# 110   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#      2020  2021  2022  2023
# 110   NaN   NaN   NaN   NaN
#
# [1 rows x 68 columns]

# %%
# Drop the row "Not classified" as there is no use for it
df1 = df1.drop(index=110)
df1.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              1
#                  ..
# 2019              0
# 2020              0
# 2021              0
# 2022              0
# 2023              0
# Length: 68, dtype: int64

# %%
'''
in the row 'West Bank and Gaza'
replace each null before the year '' with 0
as there wasn't determined yet any populations
'''
df1[df1['Country Name']=='West Bank and Gaza']
# Out:
#            Country Name Country Code     Indicator Name Indicator Code  1960  \
# 196  West Bank and Gaza          PSE  Population, total    SP.POP.TOTL   NaN
#
#      1961  1962  1963  1964  1965  ...       2014       2015       2016  \
# 196   NaN   NaN   NaN   NaN   NaN  ...  4173398.0  4270092.0  4367088.0
#
#           2017       2018       2019       2020       2021       2022  \
# 196  4454805.0  4569087.0  4685306.0  4803269.0  4922749.0  5043612.0
#
#           2023
# 196  5165775.0
#
# [1 rows x 68 columns]

# %%
df1.loc[196] = df1.loc[196].fillna(0)

# %%
# if = 0 -> there is no null data left
df1.isna().sum().sum()
# Out:
# 0

# %%
# Check if there is any duplicates
df1.duplicated().sum()
# Out:
# 0

# %%
# descripe the 5 big numbers
df1.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02
# mean   1.153569e+08  1.169439e+08  1.190890e+08  1.217439e+08  1.244209e+08
# std    3.633716e+08  3.678394e+08  3.744658e+08  3.830636e+08  3.917027e+08
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    5.128650e+05  5.193290e+05  5.257540e+05  5.325920e+05  5.398300e+05
# 50%    3.707515e+06  3.784744e+06  3.864140e+06  3.945729e+06  4.029472e+06
# 75%    2.659658e+07  2.739996e+07  2.824217e+07  2.911412e+07  3.001357e+07
# max    3.031517e+09  3.072470e+09  3.126894e+09  3.193470e+09  3.260480e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02
# mean   1.271366e+08  1.299753e+08  1.328122e+08  1.357289e+08  1.387504e+08
# ...

# %% [markdown]
# #### Second Table Data Preprocessing

# %%
# Repeate each step again
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  265 non-null    object
#  1   Region        217 non-null    object
#  2   IncomeGroup   216 non-null    object
#  3   SpecialNotes  127 non-null    object
#  4   TableName     265 non-null    object
# dtypes: object(5)
# memory usage: 10.5+ KB

# %%
# There is too many null data, so we will determine them as before
df2.isna().sum()
# Out:
# Country Code      0
# Region           48
# IncomeGroup      49
# SpecialNotes    138
# TableName         0
# dtype: int64

# %%
# first, we will fix "SpecialNotes" nulls
# as is's a string Dtype we will replace each null with Emtpy value
df2[df2["SpecialNotes"].isna()]
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 5            ALB       Europe & Central Asia  Upper middle income
# 6            AND       Europe & Central Asia          High income
# 8            ARE  Middle East & North Africa          High income
# 10           ARM       Europe & Central Asia  Upper middle income
# ..           ...                         ...                  ...
# 255          VIR   Latin America & Caribbean          High income
# 256          VNM         East Asia & Pacific  Lower middle income
# 257          VUT         East Asia & Pacific  Lower middle income
# 258          WLD                         NaN                  NaN
# 260          XKX       Europe & Central Asia  Upper middle income
#
#     SpecialNotes              TableName
# 0            NaN                  Aruba
# 5            NaN                Albania
# 6            NaN                Andorra
# ...

# %%
df2.iloc[:,3] = df2.iloc[:,3].fillna('Empty')
df2.isnull().sum()
# Out:
# Country Code     0
# Region          48
# IncomeGroup     49
# SpecialNotes     0
# TableName        0
# dtype: int64

# %%
# then, we will "IncomeGroup"
df = df2[df2['IncomeGroup'].isna()]
df['Country Code'].unique()
# Out:
# array(['AFE', 'AFW', 'ARB', 'CEB', 'CSS', 'EAP', 'EAR', 'EAS', 'ECA',
#        'ECS', 'EMU', 'EUU', 'FCS', 'HIC', 'HPC', 'IBD', 'IBT', 'IDA',
#        'IDB', 'IDX', 'LAC', 'LCN', 'LDC', 'LIC', 'LMC', 'LMY', 'LTE',
#        'MEA', 'MIC', 'MNA', 'NAC', 'OED', 'OSS', 'PRE', 'PSS', 'PST',
#        'SAS', 'SSA', 'SSF', 'SST', 'TEA', 'TEC', 'TLA', 'TMN', 'TSA',
#        'TSS', 'UMC', 'VEN', 'WLD'], dtype=object)

# %%
# fix "Region" first with MY DATASET of regions
# Dictionary mapping country codes to regions
region_map = {
    'AFE': 'Africa Eastern and Southern',
    'AFW': 'Africa Western and Central',
    'ARB': 'Arab World',
    'CEB': 'Central Europe and the Baltics',
    'CSS': 'Caribbean small states',
    'EAP': 'East Asia and Pacific',
    'EAR': 'Early Arab States',
    'EAS': 'East Asia and Pacific',
    'ECA': 'Europe and Central Asia',
    'ECS': 'Europe and Central Asia',
    'EMU': 'Euro area',
    'EUU': 'European Union',
    'FCS': 'Fragile and conflict-affected situations',
    'HIC': 'High income',
    'HPC': 'Heavily indebted poor countries (HIPC)',
    'IBD': 'IBRD countries',
    'IBT': 'IBRD and IDA countries',
    'IDA': 'International Development Association',
    'IDB': 'International Development Bank',
    'IDX': 'Not identified',
    'LAC': 'Latin America and the Caribbean',
    'LCN': 'Latin America and the Caribbean',
    'LDC': 'Least developed countries',
    'LIC': 'Low income countries',
    'LMC': 'Lower middle income countries',
    'LMY': 'Low & middle income countries',
    'LTE': 'Not identified',
    'MEA': 'Middle East and North Africa',
    'MIC': 'Middle income countries',
    'MNA': 'Middle East and North Africa',
    'NAC': 'North America',
    'OED': 'OECD members',
    'OSS': 'Other small states',
    'PRE': 'Not identified',
    'PSS': 'Pacific Island small states',
    'PST': 'Not identified',
    'SAS': 'South Asia',
    'SSA': 'Sub-Saharan Africa',
    'SSF': 'Sub-Saharan Africa',
    'SST': 'Small states',
    'TEA': 'Not identified',
    'TEC': 'Not identified',
    'TLA': 'Latin America',
    'TMN': 'Not identified',
    'TSA': 'South Asia',
    'TSS': 'Small states',
    'UMC': 'Upper middle income countries',
    'VEN': 'Venezuela',
    'WLD': 'World'
}

# then, fix the "IncomeGroup" by same way (estimation)
# Dictionary mapping country codes to income groups
income_group_map = {
    'AFE': 'Low income',  # Africa Eastern and Southern generally includes low to lower middle income countries
    'AFW': 'Low income',  # Africa Western and Central
    'ARB': 'Upper middle income',  # Arab World includes upper middle income and high-income countries
    'CEB': 'Upper middle income',  # Central Europe and the Baltics
    'CSS': 'Upper middle income',  # Caribbean small states
    'EAP': 'Upper middle income',  # East Asia and Pacific
    'EAR': 'Lower middle income',  # Early Arab States, likely a mix
    'EAS': 'Upper middle income',  # East Asia and Pacific (aggregate)
    'ECA': 'Upper middle income',  # Europe and Central Asia
    'ECS': 'Upper middle income',  # Europe and Central Asia (aggregate)
    'EMU': 'High income',  # Euro area
    'EUU': 'High income',  # European Union
    'FCS': 'Low income',  # Fragile and conflict-affected situations
    'HIC': 'High income',  # High income
    'HPC': 'Low income',  # Heavily indebted poor countries (HIPC)
    'IBD': 'Upper middle income',  # IBRD countries
    'IBT': 'Upper middle income',  # IBRD and IDA countries
    'IDA': 'Low income',  # International Development Association
    'IDB': 'Upper middle income',  # International Development Bank
    'IDX': 'Not identified',
    'LAC': 'Upper middle income',  # Latin America and the Caribbean
    'LCN': 'Upper middle income',  # Latin America and the Caribbean (aggregate)
    'LDC': 'Low income',  # Least developed countries
    'LIC': 'Low income',  # Low income countries
    'LMC': 'Lower middle income',  # Lower middle income countries
    'LMY': 'Low & middle income',  # Low & middle income countries
    'LTE': 'Not identified',
    'MEA': 'Upper middle income',  # Middle East and North Africa
    'MIC': 'Middle income',  # Middle income countries
    'MNA': 'Upper middle income',  # Middle East and North Africa (aggregate)
    'NAC': 'High income',  # North America
    'OED': 'High income',  # OECD members
    'OSS': 'Upper middle income',  # Other small states
    'PRE': 'Not identified',
    'PSS': 'Upper middle income',  # Pacific Island small states
    'PST': 'Not identified',
    'SAS': 'Lower middle income',  # South Asia
    'SSA': 'Low income',  # Sub-Saharan Africa
    'SSF': 'Low income',  # Sub-Saharan Africa (aggregate)
    'SST': 'Upper middle income',  # Small states
    'TEA': 'Not identified',
    'TEC': 'Not identified',
    'TLA': 'Upper middle income',  # Latin America
    'TMN': 'Not identified',
    'TSA': 'Lower middle income',  # South Asia (aggregate)
    'TSS': 'Upper middle income',  # Small states (aggregate)
    'UMC': 'Upper middle income',  # Upper middle income countries
    'VEN': 'Upper middle income',  # Venezuela
    'WLD': 'Not identified'  # World (no specific income group)
}

# Replace NaN in 'IncomeGroup' column using the dictionary
df['IncomeGroup'] = df['Country Code'].map(income_group_map)
# Replace NaN in 'Region' column using the dictionary
df['Region'] = df['Country Code'].map(region_map)

# Now replace with the original dataframe df2
df2['Region'] = df2["Region"].fillna(df["Region"])
df2['IncomeGroup'] = df2["IncomeGroup"].fillna(df["IncomeGroup"])

df2.isnull().sum()
# Out:
# C:\Users\Eldawlia\AppData\Local\Temp\ipykernel_20224\3772888231.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IncomeGroup'] = df['Country Code'].map(income_group_map)
# C:\Users\Eldawlia\AppData\Local\Temp\ipykernel_20224\3772888231.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Region'] = df['Country Code'].map(region_map)
# Country Code    0
# Region          0
# IncomeGroup     0
# SpecialNotes    0
# TableName       0
# dtype: int64

# %%
df2.head()
# Out:
#   Country Code                       Region          IncomeGroup  \
# 0          ABW    Latin America & Caribbean          High income
# 1          AFE  Africa Eastern and Southern           Low income
# 2          AFG                   South Asia           Low income
# 3          AFW   Africa Western and Central           Low income
# 4          AGO           Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                              Empty
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName
# 0                        Aruba
# 1  Africa Eastern and Southern
# 2                  Afghanistan
# 3   Africa Western and Central
# 4                       Angola

# %%
# Check if there is any duplicates
df2.duplicated().sum()
# Out:
# 0

# %%
# descripe the 5 big numbers
df2.describe()
# Out:
#        Country Code                 Region  IncomeGroup SpecialNotes TableName
# count           265                    265          265          265       265
# unique          265                     39            7          114       265
# top             ABW  Europe & Central Asia  High income        Empty     Aruba
# freq              1                     58           90          138         1

# %% [markdown]
# ### Visualization

# %%
df1.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2014         2015         2016         2017  \
# ...

# %%
# Sum the values from '1960' to '2023' and create a new column 'Total Sum'
df1['Total Sum'] = df1.loc[:, 1960:2023].sum(axis=1)

# Get top 5 for 'Country Name'
top_countries = df1.groupby('Country Name')['Total Sum'].sum().nlargest(5)

# Get top 5 for 'Country Code'
top_codes = df1.groupby('Country Code')['Total Sum'].sum().nlargest(5)

# Get top 5 for 'Indicator Name'
top_indicators = df1.groupby('Indicator Name')['Total Sum'].sum().nlargest(5)

# %%
import matplotlib.pyplot as plt

# Plot histograms
plt.figure(figsize=(14, 10))

# Overall histogram
plt.subplot(2, 2, 1)
plt.hist(df1['Total Sum'], bins=20, color='blue', alpha=0.7)
plt.title('Overall Distribution of Total Sum')

# Top 5 Country Names histogram
plt.subplot(2, 2, 2)
top_countries.plot(kind='bar', color='green', alpha=0.7)
plt.title('Top 5 Country Names by Total Sum')
plt.xticks(rotation=45)

# Top 5 Country Codes histogram
plt.subplot(2, 2, 3)
top_codes.plot(kind='bar', color='red', alpha=0.7)
plt.title('Top 5 Country Codes by Total Sum')
plt.xticks(rotation=45)

# Top 5 Indicator Names histogram
plt.subplot(2, 2, 4)
top_indicators.plot(kind='bar', color='orange', alpha=0.7)
plt.title('Top 5 Indicator Names by Total Sum')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
